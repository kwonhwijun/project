# %%
import requests
import pandas as pd

api_key = 'ebl8Ut/J2dsO84047u5ZUjBH53zpBM3YTtMLdGH0FkE6Ukn1z8Hy9WN45TvTQ+bdBRQctFDMT7GBZHqttCA8yg=='

url = "http://apis.data.go.kr/1160100/service/GetStockSecuritiesInfoService/getStockPriceInfo"
params = {
    "serviceKey": api_key,
    "numOfRows": 100,
    "pageNo": 1,
    "basDt": 20230717,
}

response = requests.get(url, params=params)
print(response)
content = response.text
print(content)
# Out:
# <Response [200]>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL SERVICE.</resultMsg>
#     </header>
#     <body>
#         <numOfRows>100</numOfRows>
#         <pageNo>1</pageNo>
#         <totalCount>2728</totalCount>
#         <items>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>900110</srtnCd>
#                 <isinCd>HK0000057197</isinCd>
#                 <itmsNm>이스트아시아홀딩스</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>150</clpr>
#                 <vs>-1</vs>
#                 <fltRt>-.66</fltRt>
#                 <mkp>151</mkp>
#                 <hipr>151</hipr>
#                 <lopr>148</lopr>
#                 <trqu>1780351</trqu>
#                 <trPrc>266398657</trPrc>
#                 <lstgStCnt>291932050</lstgStCnt>
#                 <mrktTotAmt>43789807500</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>900270</srtnCd>
#                 <isinCd>HK0000214814</isinCd>
#                 <itmsNm>헝셩그룹</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>298</clpr>
#                 <vs>-3</vs>
#                 <fltRt>-1</fltRt>
#                 <mkp>298</mkp>
#                 <hipr>301</hipr>
#                 <lopr>294</lopr>
#                 <trqu>373526</trqu>
#                 <trPrc>110793674</trPrc>
#                 <lstgStCnt>85682000</lstgStCnt>
#                 <mrktTotAmt>25533236000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>900260</srtnCd>
#                 <isinCd>HK0000295359</isinCd>
#                 <itmsNm>로스웰</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>935</clpr>
#                 <vs>11</vs>
#                 <fltRt>1.19</fltRt>
#                 <mkp>929</mkp>
#                 <hipr>952</hipr>
#                 <lopr>917</lopr>
#                 <trqu>92632</trqu>
#                 <trPrc>86521205</trPrc>
#                 <lstgStCnt>36031288</lstgStCnt>
#                 <mrktTotAmt>33689254280</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>900290</srtnCd>
#                 <isinCd>HK0000307485</isinCd>
#                 <itmsNm>GRT</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>4635</clpr>
#                 <vs>-165</vs>
#                 <fltRt>-3.44</fltRt>
#                 <mkp>4800</mkp>
#                 <hipr>4805</hipr>
#                 <lopr>4600</lopr>
#                 <trqu>47663</trqu>
#                 <trPrc>223141490</trPrc>
#                 <lstgStCnt>67375000</lstgStCnt>
#                 <mrktTotAmt>312283125000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>900300</srtnCd>
#                 <isinCd>HK0000312568</isinCd>
#                 <itmsNm>오가닉티코스메틱</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>163</clpr>
#                 <vs>-2</vs>
#                 <fltRt>-1.21</fltRt>
#                 <mkp>165</mkp>
#                 <hipr>167</hipr>
#                 <lopr>161</lopr>
#                 <trqu>1536752</trqu>
#                 <trPrc>250246581</trPrc>
#                 <lstgStCnt>245263481</lstgStCnt>
#                 <mrktTotAmt>39977947403</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>900310</srtnCd>
#                 <isinCd>HK0000341732</isinCd>
#                 <itmsNm>컬러레이</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>1103</clpr>
#                 <vs>-11</vs>
#                 <fltRt>-.99</fltRt>
#                 <mkp>1104</mkp>
#                 <hipr>1113</hipr>
#                 <lopr>1091</lopr>
#                 <trqu>172873</trqu>
#                 <trPrc>190031273</trPrc>
#                 <lstgStCnt>64041675</lstgStCnt>
#                 <mrktTotAmt>70637967525</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>900340</srtnCd>
#                 <isinCd>HK0000449303</isinCd>
#                 <itmsNm>윙입푸드</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>980</clpr>
#                 <vs>29</vs>
#                 <fltRt>3.05</fltRt>
#                 <mkp>962</mkp>
#                 <hipr>980</hipr>
#                 <lopr>952</lopr>
#                 <trqu>77890</trqu>
#                 <trPrc>75272757</trPrc>
#                 <lstgStCnt>47973428</lstgStCnt>
#                 <mrktTotAmt>47013959440</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000020</srtnCd>
#                 <isinCd>KR7000020008</isinCd>
#                 <itmsNm>동화약품</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>10280</clpr>
#                 <vs>200</vs>
#                 <fltRt>1.98</fltRt>
#                 <mkp>10130</mkp>
#                 <hipr>10280</hipr>
#                 <lopr>10000</lopr>
#                 <trqu>93975</trqu>
#                 <trPrc>956456670</trPrc>
#                 <lstgStCnt>27931470</lstgStCnt>
#                 <mrktTotAmt>287135511600</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000040</srtnCd>
#                 <isinCd>KR7000040006</isinCd>
#                 <itmsNm>KR모터스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>536</clpr>
#                 <vs>-10</vs>
#                 <fltRt>-1.83</fltRt>
#                 <mkp>550</mkp>
#                 <hipr>551</hipr>
#                 <lopr>533</lopr>
#                 <trqu>333345</trqu>
#                 <trPrc>179094853</trPrc>
#                 <lstgStCnt>96138465</lstgStCnt>
#                 <mrktTotAmt>51530217240</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000050</srtnCd>
#                 <isinCd>KR7000050005</isinCd>
#                 <itmsNm>경방</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>9770</clpr>
#                 <vs>220</vs>
#                 <fltRt>2.3</fltRt>
#                 <mkp>9800</mkp>
#                 <hipr>9800</hipr>
#                 <lopr>9560</lopr>
#                 <trqu>7888</trqu>
#                 <trPrc>76196880</trPrc>
#                 <lstgStCnt>27415270</lstgStCnt>
#                 <mrktTotAmt>267847187900</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000070</srtnCd>
#                 <isinCd>KR7000070003</isinCd>
#                 <itmsNm>삼양홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>71700</clpr>
#                 <vs>-200</vs>
#                 <fltRt>-.28</fltRt>
#                 <mkp>71700</mkp>
#                 <hipr>72200</hipr>
#                 <lopr>71100</lopr>
#                 <trqu>2152</trqu>
#                 <trPrc>153772600</trPrc>
#                 <lstgStCnt>8564271</lstgStCnt>
#                 <mrktTotAmt>614058230700</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000075</srtnCd>
#                 <isinCd>KR7000071001</isinCd>
#                 <itmsNm>삼양홀딩스우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>54000</clpr>
#                 <vs>800</vs>
#                 <fltRt>1.5</fltRt>
#                 <mkp>53300</mkp>
#                 <hipr>54000</hipr>
#                 <lopr>53300</lopr>
#                 <trqu>48</trqu>
#                 <trPrc>2564000</trPrc>
#                 <lstgStCnt>304058</lstgStCnt>
#                 <mrktTotAmt>16419132000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000080</srtnCd>
#                 <isinCd>KR7000080002</isinCd>
#                 <itmsNm>하이트진로</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>21100</clpr>
#                 <vs>50</vs>
#                 <fltRt>.24</fltRt>
#                 <mkp>21100</mkp>
#                 <hipr>21300</hipr>
#                 <lopr>21000</lopr>
#                 <trqu>162852</trqu>
#                 <trPrc>3444512500</trPrc>
#                 <lstgStCnt>70133611</lstgStCnt>
#                 <mrktTotAmt>1479819192100</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000087</srtnCd>
#                 <isinCd>KR7000082008</isinCd>
#                 <itmsNm>하이트진로2우B</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>16090</clpr>
#                 <vs>30</vs>
#                 <fltRt>.19</fltRt>
#                 <mkp>16100</mkp>
#                 <hipr>16100</hipr>
#                 <lopr>16040</lopr>
#                 <trqu>371</trqu>
#                 <trPrc>5959000</trPrc>
#                 <lstgStCnt>1130138</lstgStCnt>
#                 <mrktTotAmt>18183920420</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000100</srtnCd>
#                 <isinCd>KR7000100008</isinCd>
#                 <itmsNm>유한양행</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>58300</clpr>
#                 <vs>-1200</vs>
#                 <fltRt>-2.02</fltRt>
#                 <mkp>59500</mkp>
#                 <hipr>59600</hipr>
#                 <lopr>58100</lopr>
#                 <trqu>142862</trqu>
#                 <trPrc>8373356300</trPrc>
#                 <lstgStCnt>76638657</lstgStCnt>
#                 <mrktTotAmt>4468033703100</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000105</srtnCd>
#                 <isinCd>KR7000101006</isinCd>
#                 <itmsNm>유한양행우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>54100</clpr>
#                 <vs>-200</vs>
#                 <fltRt>-.37</fltRt>
#                 <mkp>54300</mkp>
#                 <hipr>54800</hipr>
#                 <lopr>53500</lopr>
#                 <trqu>884</trqu>
#                 <trPrc>47569100</trPrc>
#                 <lstgStCnt>1180940</lstgStCnt>
#                 <mrktTotAmt>63888854000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000120</srtnCd>
#                 <isinCd>KR7000120006</isinCd>
#                 <itmsNm>CJ대한통운</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>75200</clpr>
#                 <vs>0</vs>
#                 <fltRt>0</fltRt>
#                 <mkp>75000</mkp>
#                 <hipr>75600</hipr>
#                 <lopr>73400</lopr>
#                 <trqu>37849</trqu>
#                 <trPrc>2836284000</trPrc>
#                 <lstgStCnt>22812344</lstgStCnt>
#                 <mrktTotAmt>1715488268800</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000140</srtnCd>
#                 <isinCd>KR7000140004</isinCd>
#                 <itmsNm>하이트진로홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>9270</clpr>
#                 <vs>-30</vs>
#                 <fltRt>-.32</fltRt>
#                 <mkp>9300</mkp>
#                 <hipr>9310</hipr>
#                 <lopr>9220</lopr>
#                 <trqu>3951</trqu>
#                 <trPrc>36593520</trPrc>
#                 <lstgStCnt>23206765</lstgStCnt>
#                 <mrktTotAmt>215126711550</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000145</srtnCd>
#                 <isinCd>KR7000141002</isinCd>
#                 <itmsNm>하이트진로홀딩스우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>12030</clpr>
#                 <vs>-330</vs>
#                 <fltRt>-2.67</fltRt>
#                 <mkp>12200</mkp>
#                 <hipr>12350</hipr>
#                 <lopr>12030</lopr>
#                 <trqu>646</trqu>
#                 <trPrc>7841170</trPrc>
#                 <lstgStCnt>470810</lstgStCnt>
#                 <mrktTotAmt>5663844300</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000150</srtnCd>
#                 <isinCd>KR7000150003</isinCd>
#                 <itmsNm>두산</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>86600</clpr>
#                 <vs>-1100</vs>
#                 <fltRt>-1.25</fltRt>
#                 <mkp>87700</mkp>
#                 <hipr>87700</hipr>
#                 <lopr>86100</lopr>
#                 <trqu>60667</trqu>
#                 <trPrc>5253494700</trPrc>
#                 <lstgStCnt>16523835</lstgStCnt>
#                 <mrktTotAmt>1430964111000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000155</srtnCd>
#                 <isinCd>KR7000151001</isinCd>
#                 <itmsNm>두산우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>50500</clpr>
#                 <vs>-800</vs>
#                 <fltRt>-1.56</fltRt>
#                 <mkp>52000</mkp>
#                 <hipr>52000</hipr>
#                 <lopr>50300</lopr>
#                 <trqu>4156</trqu>
#                 <trPrc>210895300</trPrc>
#                 <lstgStCnt>3996462</lstgStCnt>
#                 <mrktTotAmt>201821331000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000157</srtnCd>
#                 <isinCd>KR7000152009</isinCd>
#                 <itmsNm>두산2우B</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>86800</clpr>
#                 <vs>800</vs>
#                 <fltRt>.93</fltRt>
#                 <mkp>87000</mkp>
#                 <hipr>88400</hipr>
#                 <lopr>86000</lopr>
#                 <trqu>542</trqu>
#                 <trPrc>47322500</trPrc>
#                 <lstgStCnt>893038</lstgStCnt>
#                 <mrktTotAmt>77515698400</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000180</srtnCd>
#                 <isinCd>KR7000180000</isinCd>
#                 <itmsNm>성창기업지주</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>2005</clpr>
#                 <vs>-25</vs>
#                 <fltRt>-1.23</fltRt>
#                 <mkp>2030</mkp>
#                 <hipr>2030</hipr>
#                 <lopr>2000</lopr>
#                 <trqu>138603</trqu>
#                 <trPrc>278159070</trPrc>
#                 <lstgStCnt>69751600</lstgStCnt>
#                 <mrktTotAmt>139851958000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000210</srtnCd>
#                 <isinCd>KR7000210005</isinCd>
#                 <itmsNm>DL</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>38400</clpr>
#                 <vs>100</vs>
#                 <fltRt>.26</fltRt>
#                 <mkp>38300</mkp>
#                 <hipr>39150</hipr>
#                 <lopr>38050</lopr>
#                 <trqu>53390</trqu>
#                 <trPrc>2058906550</trPrc>
#                 <lstgStCnt>20955884</lstgStCnt>
#                 <mrktTotAmt>804705945600</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000215</srtnCd>
#                 <isinCd>KR7000211003</isinCd>
#                 <itmsNm>DL우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>22800</clpr>
#                 <vs>100</vs>
#                 <fltRt>.44</fltRt>
#                 <mkp>23250</mkp>
#                 <hipr>23250</hipr>
#                 <lopr>22650</lopr>
#                 <trqu>621</trqu>
#                 <trPrc>14104800</trPrc>
#                 <lstgStCnt>1686115</lstgStCnt>
#                 <mrktTotAmt>38443422000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000220</srtnCd>
#                 <isinCd>KR7000220004</isinCd>
#                 <itmsNm>유유제약</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>5080</clpr>
#                 <vs>0</vs>
#                 <fltRt>0</fltRt>
#                 <mkp>5070</mkp>
#                 <hipr>5110</hipr>
#                 <lopr>5000</lopr>
#                 <trqu>24252</trqu>
#                 <trPrc>121739030</trPrc>
#                 <lstgStCnt>17232351</lstgStCnt>
#                 <mrktTotAmt>87540343080</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000225</srtnCd>
#                 <isinCd>KR7000221002</isinCd>
#                 <itmsNm>유유제약1우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>5250</clpr>
#                 <vs>-60</vs>
#                 <fltRt>-1.13</fltRt>
#                 <mkp>5310</mkp>
#                 <hipr>5310</hipr>
#                 <lopr>5200</lopr>
#                 <trqu>13516</trqu>
#                 <trPrc>70956690</trPrc>
#                 <lstgStCnt>2266930</lstgStCnt>
#                 <mrktTotAmt>11901382500</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000227</srtnCd>
#                 <isinCd>KR7000222000</isinCd>
#                 <itmsNm>유유제약2우B</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>11310</clpr>
#                 <vs>-300</vs>
#                 <fltRt>-2.58</fltRt>
#                 <mkp>11600</mkp>
#                 <hipr>11620</hipr>
#                 <lopr>11300</lopr>
#                 <trqu>846</trqu>
#                 <trPrc>9608230</trPrc>
#                 <lstgStCnt>325560</lstgStCnt>
#                 <mrktTotAmt>3682083600</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000230</srtnCd>
#                 <isinCd>KR7000230003</isinCd>
#                 <itmsNm>일동홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>10000</clpr>
#                 <vs>-540</vs>
#                 <fltRt>-5.12</fltRt>
#                 <mkp>10290</mkp>
#                 <hipr>10560</hipr>
#                 <lopr>9830</lopr>
#                 <trqu>156704</trqu>
#                 <trPrc>1579036650</trPrc>
#                 <lstgStCnt>11540400</lstgStCnt>
#                 <mrktTotAmt>115404000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000240</srtnCd>
#                 <isinCd>KR7000240002</isinCd>
#                 <itmsNm>한국앤컴퍼니</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>11750</clpr>
#                 <vs>-50</vs>
#                 <fltRt>-.42</fltRt>
#                 <mkp>11740</mkp>
#                 <hipr>11870</hipr>
#                 <lopr>11620</lopr>
#                 <trqu>79182</trqu>
#                 <trPrc>926496170</trPrc>
#                 <lstgStCnt>94935240</lstgStCnt>
#                 <mrktTotAmt>1115489070000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000250</srtnCd>
#                 <isinCd>KR7000250001</isinCd>
#                 <itmsNm>삼천당제약</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>54300</clpr>
#                 <vs>400</vs>
#                 <fltRt>.74</fltRt>
#                 <mkp>53400</mkp>
#                 <hipr>54900</hipr>
#                 <lopr>52900</lopr>
#                 <trqu>151599</trqu>
#                 <trPrc>8200181600</trPrc>
#                 <lstgStCnt>23066794</lstgStCnt>
#                 <mrktTotAmt>1252526914200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000270</srtnCd>
#                 <isinCd>KR7000270009</isinCd>
#                 <itmsNm>기아</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>86600</clpr>
#                 <vs>-2100</vs>
#                 <fltRt>-2.37</fltRt>
#                 <mkp>88400</mkp>
#                 <hipr>89100</hipr>
#                 <lopr>86500</lopr>
#                 <trqu>968236</trqu>
#                 <trPrc>84557136500</trPrc>
#                 <lstgStCnt>402044203</lstgStCnt>
#                 <mrktTotAmt>34817027979800</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000300</srtnCd>
#                 <isinCd>KR7000300004</isinCd>
#                 <itmsNm>대유플러스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>1019</clpr>
#                 <vs>32</vs>
#                 <fltRt>3.24</fltRt>
#                 <mkp>987</mkp>
#                 <hipr>1135</hipr>
#                 <lopr>964</lopr>
#                 <trqu>22186975</trqu>
#                 <trPrc>23864185529</trPrc>
#                 <lstgStCnt>126346457</lstgStCnt>
#                 <mrktTotAmt>128747039683</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000320</srtnCd>
#                 <isinCd>KR7000320002</isinCd>
#                 <itmsNm>노루홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>11560</clpr>
#                 <vs>410</vs>
#                 <fltRt>3.68</fltRt>
#                 <mkp>11190</mkp>
#                 <hipr>11600</hipr>
#                 <lopr>11100</lopr>
#                 <trqu>73045</trqu>
#                 <trPrc>836210170</trPrc>
#                 <lstgStCnt>13291151</lstgStCnt>
#                 <mrktTotAmt>153645705560</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000325</srtnCd>
#                 <isinCd>KR7000321000</isinCd>
#                 <itmsNm>노루홀딩스우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>20950</clpr>
#                 <vs>50</vs>
#                 <fltRt>.24</fltRt>
#                 <mkp>20700</mkp>
#                 <hipr>21000</hipr>
#                 <lopr>20700</lopr>
#                 <trqu>945</trqu>
#                 <trPrc>19783550</trPrc>
#                 <lstgStCnt>243559</lstgStCnt>
#                 <mrktTotAmt>5102561050</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000370</srtnCd>
#                 <isinCd>KR7000370007</isinCd>
#                 <itmsNm>한화손해보험</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>3995</clpr>
#                 <vs>-55</vs>
#                 <fltRt>-1.36</fltRt>
#                 <mkp>4050</mkp>
#                 <hipr>4065</hipr>
#                 <lopr>3985</lopr>
#                 <trqu>105240</trqu>
#                 <trPrc>421270935</trPrc>
#                 <lstgStCnt>116738915</lstgStCnt>
#                 <mrktTotAmt>466371965425</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000390</srtnCd>
#                 <isinCd>KR7000390005</isinCd>
#                 <itmsNm>삼화페인트</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>6620</clpr>
#                 <vs>140</vs>
#                 <fltRt>2.16</fltRt>
#                 <mkp>6480</mkp>
#                 <hipr>6640</hipr>
#                 <lopr>6480</lopr>
#                 <trqu>79323</trqu>
#                 <trPrc>520313960</trPrc>
#                 <lstgStCnt>27203469</lstgStCnt>
#                 <mrktTotAmt>180086964780</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000400</srtnCd>
#                 <isinCd>KR7000400002</isinCd>
#                 <itmsNm>롯데손해보험</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>1684</clpr>
#                 <vs>-17</vs>
#                 <fltRt>-1</fltRt>
#                 <mkp>1701</mkp>
#                 <hipr>1715</hipr>
#                 <lopr>1676</lopr>
#                 <trqu>130754</trqu>
#                 <trPrc>220509763</trPrc>
#                 <lstgStCnt>310336320</lstgStCnt>
#                 <mrktTotAmt>522606362880</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000430</srtnCd>
#                 <isinCd>KR7000430009</isinCd>
#                 <itmsNm>대원강업</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>6800</clpr>
#                 <vs>-170</vs>
#                 <fltRt>-2.44</fltRt>
#                 <mkp>6820</mkp>
#                 <hipr>6970</hipr>
#                 <lopr>6560</lopr>
#                 <trqu>3868138</trqu>
#                 <trPrc>26213637020</trPrc>
#                 <lstgStCnt>62000000</lstgStCnt>
#                 <mrktTotAmt>421600000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000440</srtnCd>
#                 <isinCd>KR7000440008</isinCd>
#                 <itmsNm>중앙에너비스</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>18640</clpr>
#                 <vs>-310</vs>
#                 <fltRt>-1.64</fltRt>
#                 <mkp>18950</mkp>
#                 <hipr>18950</hipr>
#                 <lopr>18500</lopr>
#                 <trqu>10716</trqu>
#                 <trPrc>199928990</trPrc>
#                 <lstgStCnt>6227130</lstgStCnt>
#                 <mrktTotAmt>116073703200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000480</srtnCd>
#                 <isinCd>KR7000480004</isinCd>
#                 <itmsNm>조선내화</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>21200</clpr>
#                 <vs>0</vs>
#                 <fltRt>0</fltRt>
#                 <mkp>0</mkp>
#                 <hipr>0</hipr>
#                 <lopr>0</lopr>
#                 <trqu>0</trqu>
#                 <trPrc>0</trPrc>
#                 <lstgStCnt>40000000</lstgStCnt>
#                 <mrktTotAmt>848000000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000490</srtnCd>
#                 <isinCd>KR7000490003</isinCd>
#                 <itmsNm>대동</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>11400</clpr>
#                 <vs>30</vs>
#                 <fltRt>.26</fltRt>
#                 <mkp>11480</mkp>
#                 <hipr>11670</hipr>
#                 <lopr>11360</lopr>
#                 <trqu>239471</trqu>
#                 <trPrc>2758201650</trPrc>
#                 <lstgStCnt>24065625</lstgStCnt>
#                 <mrktTotAmt>274348125000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000500</srtnCd>
#                 <isinCd>KR7000500009</isinCd>
#                 <itmsNm>가온전선</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>20700</clpr>
#                 <vs>-250</vs>
#                 <fltRt>-1.19</fltRt>
#                 <mkp>20950</mkp>
#                 <hipr>20950</hipr>
#                 <lopr>20250</lopr>
#                 <trqu>41436</trqu>
#                 <trPrc>853720150</trPrc>
#                 <lstgStCnt>6358926</lstgStCnt>
#                 <mrktTotAmt>131629768200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000520</srtnCd>
#                 <isinCd>KR7000520007</isinCd>
#                 <itmsNm>삼일제약</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>7200</clpr>
#                 <vs>-140</vs>
#                 <fltRt>-1.91</fltRt>
#                 <mkp>7270</mkp>
#                 <hipr>7330</hipr>
#                 <lopr>7200</lopr>
#                 <trqu>70923</trqu>
#                 <trPrc>512552380</trPrc>
#                 <lstgStCnt>15009757</lstgStCnt>
#                 <mrktTotAmt>108070250400</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000540</srtnCd>
#                 <isinCd>KR7000540005</isinCd>
#                 <itmsNm>흥국화재</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>3015</clpr>
#                 <vs>-25</vs>
#                 <fltRt>-.82</fltRt>
#                 <mkp>3055</mkp>
#                 <hipr>3055</hipr>
#                 <lopr>3000</lopr>
#                 <trqu>31518</trqu>
#                 <trPrc>95121535</trPrc>
#                 <lstgStCnt>64242645</lstgStCnt>
#                 <mrktTotAmt>193691574675</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000545</srtnCd>
#                 <isinCd>KR7000541003</isinCd>
#                 <itmsNm>흥국화재우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>5410</clpr>
#                 <vs>-80</vs>
#                 <fltRt>-1.46</fltRt>
#                 <mkp>5420</mkp>
#                 <hipr>5570</hipr>
#                 <lopr>5410</lopr>
#                 <trqu>6654</trqu>
#                 <trPrc>36160110</trPrc>
#                 <lstgStCnt>768000</lstgStCnt>
#                 <mrktTotAmt>4154880000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000590</srtnCd>
#                 <isinCd>KR7000590000</isinCd>
#                 <itmsNm>CS홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>61600</clpr>
#                 <vs>400</vs>
#                 <fltRt>.65</fltRt>
#                 <mkp>61600</mkp>
#                 <hipr>62200</hipr>
#                 <lopr>61100</lopr>
#                 <trqu>1062</trqu>
#                 <trPrc>65399000</trPrc>
#                 <lstgStCnt>1154482</lstgStCnt>
#                 <mrktTotAmt>71116091200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000640</srtnCd>
#                 <isinCd>KR7000640003</isinCd>
#                 <itmsNm>동아쏘시오홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>81000</clpr>
#                 <vs>-2200</vs>
#                 <fltRt>-2.64</fltRt>
#                 <mkp>83200</mkp>
#                 <hipr>83200</hipr>
#                 <lopr>80500</lopr>
#                 <trqu>7562</trqu>
#                 <trPrc>615984600</trPrc>
#                 <lstgStCnt>6348913</lstgStCnt>
#                 <mrktTotAmt>514261953000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000650</srtnCd>
#                 <isinCd>KR7000650002</isinCd>
#                 <itmsNm>천일고속</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>51900</clpr>
#                 <vs>-100</vs>
#                 <fltRt>-.19</fltRt>
#                 <mkp>52400</mkp>
#                 <hipr>52400</hipr>
#                 <lopr>51800</lopr>
#                 <trqu>46</trqu>
#                 <trPrc>2397600</trPrc>
#                 <lstgStCnt>1429220</lstgStCnt>
#                 <mrktTotAmt>74176518000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000660</srtnCd>
#                 <isinCd>KR7000660001</isinCd>
#                 <itmsNm>SK하이닉스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>117200</clpr>
#                 <vs>-800</vs>
#                 <fltRt>-.68</fltRt>
#                 <mkp>116900</mkp>
#                 <hipr>118700</hipr>
#                 <lopr>116000</lopr>
#                 <trqu>2427281</trqu>
#                 <trPrc>284032099050</trPrc>
#                 <lstgStCnt>728002365</lstgStCnt>
#                 <mrktTotAmt>85321877178000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000670</srtnCd>
#                 <isinCd>KR7000670000</isinCd>
#                 <itmsNm>영풍</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>547000</clpr>
#                 <vs>-11000</vs>
#                 <fltRt>-1.97</fltRt>
#                 <mkp>553000</mkp>
#                 <hipr>562000</hipr>
#                 <lopr>540000</lopr>
#                 <trqu>919</trqu>
#                 <trPrc>506076000</trPrc>
#                 <lstgStCnt>1842040</lstgStCnt>
#                 <mrktTotAmt>1007595880000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000680</srtnCd>
#                 <isinCd>KR7000680009</isinCd>
#                 <itmsNm>LS네트웍스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>2770</clpr>
#                 <vs>-45</vs>
#                 <fltRt>-1.6</fltRt>
#                 <mkp>2790</mkp>
#                 <hipr>2835</hipr>
#                 <lopr>2770</lopr>
#                 <trqu>15084</trqu>
#                 <trPrc>42285505</trPrc>
#                 <lstgStCnt>78803016</lstgStCnt>
#                 <mrktTotAmt>218284354320</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000700</srtnCd>
#                 <isinCd>KR7000700005</isinCd>
#                 <itmsNm>유수홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>5930</clpr>
#                 <vs>-50</vs>
#                 <fltRt>-.84</fltRt>
#                 <mkp>5980</mkp>
#                 <hipr>5980</hipr>
#                 <lopr>5900</lopr>
#                 <trqu>9491</trqu>
#                 <trPrc>56273580</trPrc>
#                 <lstgStCnt>26041812</lstgStCnt>
#                 <mrktTotAmt>154427945160</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000720</srtnCd>
#                 <isinCd>KR7000720003</isinCd>
#                 <itmsNm>현대건설</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>39000</clpr>
#                 <vs>1500</vs>
#                 <fltRt>4</fltRt>
#                 <mkp>38750</mkp>
#                 <hipr>39550</hipr>
#                 <lopr>38300</lopr>
#                 <trqu>2862199</trqu>
#                 <trPrc>111601534850</trPrc>
#                 <lstgStCnt>111355765</lstgStCnt>
#                 <mrktTotAmt>4342874835000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000725</srtnCd>
#                 <isinCd>KR7000721001</isinCd>
#                 <itmsNm>현대건설우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>61900</clpr>
#                 <vs>1600</vs>
#                 <fltRt>2.65</fltRt>
#                 <mkp>66000</mkp>
#                 <hipr>66000</hipr>
#                 <lopr>61100</lopr>
#                 <trqu>15375</trqu>
#                 <trPrc>983726600</trPrc>
#                 <lstgStCnt>1054693</lstgStCnt>
#                 <mrktTotAmt>65285496700</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000760</srtnCd>
#                 <isinCd>KR7000760009</isinCd>
#                 <itmsNm>이화산업</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>19300</clpr>
#                 <vs>690</vs>
#                 <fltRt>3.71</fltRt>
#                 <mkp>18610</mkp>
#                 <hipr>19300</hipr>
#                 <lopr>18000</lopr>
#                 <trqu>8816</trqu>
#                 <trPrc>164195160</trPrc>
#                 <lstgStCnt>2800000</lstgStCnt>
#                 <mrktTotAmt>54040000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000810</srtnCd>
#                 <isinCd>KR7000810002</isinCd>
#                 <itmsNm>삼성화재</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>240500</clpr>
#                 <vs>-4000</vs>
#                 <fltRt>-1.64</fltRt>
#                 <mkp>242500</mkp>
#                 <hipr>244500</hipr>
#                 <lopr>238500</lopr>
#                 <trqu>70247</trqu>
#                 <trPrc>16942995500</trPrc>
#                 <lstgStCnt>47374837</lstgStCnt>
#                 <mrktTotAmt>11393648298500</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000815</srtnCd>
#                 <isinCd>KR7000811000</isinCd>
#                 <itmsNm>삼성화재우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>172600</clpr>
#                 <vs>-2000</vs>
#                 <fltRt>-1.15</fltRt>
#                 <mkp>174000</mkp>
#                 <hipr>174000</hipr>
#                 <lopr>170900</lopr>
#                 <trqu>6759</trqu>
#                 <trPrc>1165930900</trPrc>
#                 <lstgStCnt>3192000</lstgStCnt>
#                 <mrktTotAmt>550939200000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000850</srtnCd>
#                 <isinCd>KR7000850008</isinCd>
#                 <itmsNm>화천기공</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>37450</clpr>
#                 <vs>-200</vs>
#                 <fltRt>-.53</fltRt>
#                 <mkp>37650</mkp>
#                 <hipr>37900</hipr>
#                 <lopr>37000</lopr>
#                 <trqu>2253</trqu>
#                 <trPrc>84065550</trPrc>
#                 <lstgStCnt>2200000</lstgStCnt>
#                 <mrktTotAmt>82390000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000860</srtnCd>
#                 <isinCd>KR7000860007</isinCd>
#                 <itmsNm>강남제비스코</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>23100</clpr>
#                 <vs>-150</vs>
#                 <fltRt>-.65</fltRt>
#                 <mkp>22900</mkp>
#                 <hipr>23350</hipr>
#                 <lopr>22850</lopr>
#                 <trqu>10441</trqu>
#                 <trPrc>240978600</trPrc>
#                 <lstgStCnt>6500000</lstgStCnt>
#                 <mrktTotAmt>150150000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000880</srtnCd>
#                 <isinCd>KR7000880005</isinCd>
#                 <itmsNm>한화</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>30850</clpr>
#                 <vs>-1300</vs>
#                 <fltRt>-4.04</fltRt>
#                 <mkp>32250</mkp>
#                 <hipr>32300</hipr>
#                 <lopr>30650</lopr>
#                 <trqu>358521</trqu>
#                 <trPrc>11187136300</trPrc>
#                 <lstgStCnt>74958735</lstgStCnt>
#                 <mrktTotAmt>2312476974750</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000885</srtnCd>
#                 <isinCd>KR7000881003</isinCd>
#                 <itmsNm>한화우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>33300</clpr>
#                 <vs>-100</vs>
#                 <fltRt>-.3</fltRt>
#                 <mkp>33400</mkp>
#                 <hipr>33400</hipr>
#                 <lopr>32900</lopr>
#                 <trqu>517</trqu>
#                 <trPrc>17048100</trPrc>
#                 <lstgStCnt>479294</lstgStCnt>
#                 <mrktTotAmt>15960490200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>00088K</srtnCd>
#                 <isinCd>KR700088K015</isinCd>
#                 <itmsNm>한화3우B</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>15130</clpr>
#                 <vs>-260</vs>
#                 <fltRt>-1.69</fltRt>
#                 <mkp>15400</mkp>
#                 <hipr>15400</hipr>
#                 <lopr>15030</lopr>
#                 <trqu>24554</trqu>
#                 <trPrc>371835670</trPrc>
#                 <lstgStCnt>22472000</lstgStCnt>
#                 <mrktTotAmt>340001360000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000890</srtnCd>
#                 <isinCd>KR7000890004</isinCd>
#                 <itmsNm>보해양조</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>586</clpr>
#                 <vs>1</vs>
#                 <fltRt>.17</fltRt>
#                 <mkp>581</mkp>
#                 <hipr>586</hipr>
#                 <lopr>580</lopr>
#                 <trqu>218089</trqu>
#                 <trPrc>126924519</trPrc>
#                 <lstgStCnt>139120129</lstgStCnt>
#                 <mrktTotAmt>81524395594</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000910</srtnCd>
#                 <isinCd>KR7000910000</isinCd>
#                 <itmsNm>유니온</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>6480</clpr>
#                 <vs>60</vs>
#                 <fltRt>.93</fltRt>
#                 <mkp>6410</mkp>
#                 <hipr>6490</hipr>
#                 <lopr>6270</lopr>
#                 <trqu>211147</trqu>
#                 <trPrc>1349676990</trPrc>
#                 <lstgStCnt>15611619</lstgStCnt>
#                 <mrktTotAmt>101163291120</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000950</srtnCd>
#                 <isinCd>KR7000950006</isinCd>
#                 <itmsNm>전방</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>27850</clpr>
#                 <vs>250</vs>
#                 <fltRt>.91</fltRt>
#                 <mkp>27350</mkp>
#                 <hipr>27850</hipr>
#                 <lopr>27350</lopr>
#                 <trqu>379</trqu>
#                 <trPrc>10475550</trPrc>
#                 <lstgStCnt>1680000</lstgStCnt>
#                 <mrktTotAmt>46788000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000970</srtnCd>
#                 <isinCd>KR7000970004</isinCd>
#                 <itmsNm>한국주철관</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>7350</clpr>
#                 <vs>140</vs>
#                 <fltRt>1.94</fltRt>
#                 <mkp>7270</mkp>
#                 <hipr>7530</hipr>
#                 <lopr>7270</lopr>
#                 <trqu>73694</trqu>
#                 <trPrc>544808990</trPrc>
#                 <lstgStCnt>22800500</lstgStCnt>
#                 <mrktTotAmt>167583675000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>000990</srtnCd>
#                 <isinCd>KR7000990002</isinCd>
#                 <itmsNm>DB하이텍</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>61900</clpr>
#                 <vs>1200</vs>
#                 <fltRt>1.98</fltRt>
#                 <mkp>60700</mkp>
#                 <hipr>63000</hipr>
#                 <lopr>59800</lopr>
#                 <trqu>636282</trqu>
#                 <trPrc>39295162000</trPrc>
#                 <lstgStCnt>44398588</lstgStCnt>
#                 <mrktTotAmt>2748272597200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001000</srtnCd>
#                 <isinCd>KR7001000009</isinCd>
#                 <itmsNm>신라섬유</itmsNm>
#                 <mrktCtg>KOSDAQ</mrktCtg>
#                 <clpr>1928</clpr>
#                 <vs>12</vs>
#                 <fltRt>.63</fltRt>
#                 <mkp>1900</mkp>
#                 <hipr>1928</hipr>
#                 <lopr>1891</lopr>
#                 <trqu>25143</trqu>
#                 <trPrc>47979620</trPrc>
#                 <lstgStCnt>24277540</lstgStCnt>
#                 <mrktTotAmt>46807097120</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001020</srtnCd>
#                 <isinCd>KR7001020007</isinCd>
#                 <itmsNm>페이퍼코리아</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>878</clpr>
#                 <vs>8</vs>
#                 <fltRt>.92</fltRt>
#                 <mkp>878</mkp>
#                 <hipr>885</hipr>
#                 <lopr>861</lopr>
#                 <trqu>144689</trqu>
#                 <trPrc>126528230</trPrc>
#                 <lstgStCnt>47566810</lstgStCnt>
#                 <mrktTotAmt>41763659180</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001040</srtnCd>
#                 <isinCd>KR7001040005</isinCd>
#                 <itmsNm>CJ</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>63300</clpr>
#                 <vs>800</vs>
#                 <fltRt>1.28</fltRt>
#                 <mkp>62500</mkp>
#                 <hipr>63300</hipr>
#                 <lopr>61600</lopr>
#                 <trqu>124421</trqu>
#                 <trPrc>7816802800</trPrc>
#                 <lstgStCnt>29176998</lstgStCnt>
#                 <mrktTotAmt>1846903973400</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001045</srtnCd>
#                 <isinCd>KR7001041003</isinCd>
#                 <itmsNm>CJ우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>42850</clpr>
#                 <vs>-200</vs>
#                 <fltRt>-.46</fltRt>
#                 <mkp>43050</mkp>
#                 <hipr>43050</hipr>
#                 <lopr>42600</lopr>
#                 <trqu>1041</trqu>
#                 <trPrc>44554900</trPrc>
#                 <lstgStCnt>2260223</lstgStCnt>
#                 <mrktTotAmt>96850555550</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>00104K</srtnCd>
#                 <isinCd>KR700104K010</isinCd>
#                 <itmsNm>CJ4우(전환)</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>55300</clpr>
#                 <vs>-200</vs>
#                 <fltRt>-.36</fltRt>
#                 <mkp>55000</mkp>
#                 <hipr>55500</hipr>
#                 <lopr>54000</lopr>
#                 <trqu>4840</trqu>
#                 <trPrc>266099800</trPrc>
#                 <lstgStCnt>4226512</lstgStCnt>
#                 <mrktTotAmt>233726113600</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001060</srtnCd>
#                 <isinCd>KR7001060003</isinCd>
#                 <itmsNm>JW중외제약</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>34950</clpr>
#                 <vs>1050</vs>
#                 <fltRt>3.1</fltRt>
#                 <mkp>35300</mkp>
#                 <hipr>36000</hipr>
#                 <lopr>33900</lopr>
#                 <trqu>1051995</trqu>
#                 <trPrc>37029182750</trPrc>
#                 <lstgStCnt>22835036</lstgStCnt>
#                 <mrktTotAmt>798084508200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001065</srtnCd>
#                 <isinCd>KR7001061001</isinCd>
#                 <itmsNm>JW중외제약우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>32500</clpr>
#                 <vs>50</vs>
#                 <fltRt>.15</fltRt>
#                 <mkp>32800</mkp>
#                 <hipr>32800</hipr>
#                 <lopr>32300</lopr>
#                 <trqu>2366</trqu>
#                 <trPrc>76975150</trPrc>
#                 <lstgStCnt>335325</lstgStCnt>
#                 <mrktTotAmt>10898062500</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001067</srtnCd>
#                 <isinCd>KR7001062009</isinCd>
#                 <itmsNm>JW중외제약2우B</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>63600</clpr>
#                 <vs>3400</vs>
#                 <fltRt>5.65</fltRt>
#                 <mkp>61000</mkp>
#                 <hipr>63600</hipr>
#                 <lopr>59800</lopr>
#                 <trqu>329</trqu>
#                 <trPrc>20534800</trPrc>
#                 <lstgStCnt>205916</lstgStCnt>
#                 <mrktTotAmt>13096257600</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001070</srtnCd>
#                 <isinCd>KR7001070002</isinCd>
#                 <itmsNm>대한방직</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>12360</clpr>
#                 <vs>-120</vs>
#                 <fltRt>-.96</fltRt>
#                 <mkp>12480</mkp>
#                 <hipr>12480</hipr>
#                 <lopr>12200</lopr>
#                 <trqu>59541</trqu>
#                 <trPrc>732017630</trPrc>
#                 <lstgStCnt>5300000</lstgStCnt>
#                 <mrktTotAmt>65508000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001080</srtnCd>
#                 <isinCd>KR7001080001</isinCd>
#                 <itmsNm>만호제강</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>38200</clpr>
#                 <vs>2300</vs>
#                 <fltRt>6.41</fltRt>
#                 <mkp>36100</mkp>
#                 <hipr>38800</hipr>
#                 <lopr>35800</lopr>
#                 <trqu>16501</trqu>
#                 <trPrc>619192200</trPrc>
#                 <lstgStCnt>4150000</lstgStCnt>
#                 <mrktTotAmt>158530000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001120</srtnCd>
#                 <isinCd>KR7001120005</isinCd>
#                 <itmsNm>LX인터내셔널</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>35500</clpr>
#                 <vs>-550</vs>
#                 <fltRt>-1.53</fltRt>
#                 <mkp>36050</mkp>
#                 <hipr>36850</hipr>
#                 <lopr>35200</lopr>
#                 <trqu>396525</trqu>
#                 <trPrc>14212074050</trPrc>
#                 <lstgStCnt>38760000</lstgStCnt>
#                 <mrktTotAmt>1375980000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001130</srtnCd>
#                 <isinCd>KR7001130004</isinCd>
#                 <itmsNm>대한제분</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>129800</clpr>
#                 <vs>-100</vs>
#                 <fltRt>-.08</fltRt>
#                 <mkp>130000</mkp>
#                 <hipr>130600</hipr>
#                 <lopr>129700</lopr>
#                 <trqu>891</trqu>
#                 <trPrc>115949700</trPrc>
#                 <lstgStCnt>1690000</lstgStCnt>
#                 <mrktTotAmt>219362000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001140</srtnCd>
#                 <isinCd>KR7001140003</isinCd>
#                 <itmsNm>국보</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>7000</clpr>
#                 <vs>180</vs>
#                 <fltRt>2.64</fltRt>
#                 <mkp>6860</mkp>
#                 <hipr>7280</hipr>
#                 <lopr>6790</lopr>
#                 <trqu>597020</trqu>
#                 <trPrc>4216425940</trPrc>
#                 <lstgStCnt>12189770</lstgStCnt>
#                 <mrktTotAmt>85328390000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001200</srtnCd>
#                 <isinCd>KR7001200005</isinCd>
#                 <itmsNm>유진투자증권</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>4295</clpr>
#                 <vs>-10</vs>
#                 <fltRt>-.23</fltRt>
#                 <mkp>4305</mkp>
#                 <hipr>4410</hipr>
#                 <lopr>4255</lopr>
#                 <trqu>401960</trqu>
#                 <trPrc>1737850545</trPrc>
#                 <lstgStCnt>96866418</lstgStCnt>
#                 <mrktTotAmt>416041265310</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001210</srtnCd>
#                 <isinCd>KR7001210004</isinCd>
#                 <itmsNm>금호전기</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>1081</clpr>
#                 <vs>29</vs>
#                 <fltRt>2.76</fltRt>
#                 <mkp>1052</mkp>
#                 <hipr>1130</hipr>
#                 <lopr>1008</lopr>
#                 <trqu>1490523</trqu>
#                 <trPrc>1605012361</trPrc>
#                 <lstgStCnt>33889118</lstgStCnt>
#                 <mrktTotAmt>36634136558</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001230</srtnCd>
#                 <isinCd>KR7001230002</isinCd>
#                 <itmsNm>동국홀딩스</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>16970</clpr>
#                 <vs>-590</vs>
#                 <fltRt>-3.36</fltRt>
#                 <mkp>17590</mkp>
#                 <hipr>17870</hipr>
#                 <lopr>16830</lopr>
#                 <trqu>437447</trqu>
#                 <trPrc>7541708570</trPrc>
#                 <lstgStCnt>15926064</lstgStCnt>
#                 <mrktTotAmt>270265306080</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001250</srtnCd>
#                 <isinCd>KR7001250000</isinCd>
#                 <itmsNm>GS글로벌</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>2745</clpr>
#                 <vs>50</vs>
#                 <fltRt>1.86</fltRt>
#                 <mkp>2700</mkp>
#                 <hipr>2755</hipr>
#                 <lopr>2680</lopr>
#                 <trqu>510038</trqu>
#                 <trPrc>1387138770</trPrc>
#                 <lstgStCnt>82533764</lstgStCnt>
#                 <mrktTotAmt>226555182180</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001260</srtnCd>
#                 <isinCd>KR7001260009</isinCd>
#                 <itmsNm>남광토건</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>10430</clpr>
#                 <vs>430</vs>
#                 <fltRt>4.3</fltRt>
#                 <mkp>10290</mkp>
#                 <hipr>10550</hipr>
#                 <lopr>10000</lopr>
#                 <trqu>175841</trqu>
#                 <trPrc>1825917010</trPrc>
#                 <lstgStCnt>9832572</lstgStCnt>
#                 <mrktTotAmt>102553725960</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001270</srtnCd>
#                 <isinCd>KR7001270008</isinCd>
#                 <itmsNm>부국증권</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>21200</clpr>
#                 <vs>-150</vs>
#                 <fltRt>-.7</fltRt>
#                 <mkp>21350</mkp>
#                 <hipr>21400</hipr>
#                 <lopr>21200</lopr>
#                 <trqu>280</trqu>
#                 <trPrc>5978800</trPrc>
#                 <lstgStCnt>10369886</lstgStCnt>
#                 <mrktTotAmt>219841583200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001275</srtnCd>
#                 <isinCd>KR7001271006</isinCd>
#                 <itmsNm>부국증권우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>19030</clpr>
#                 <vs>0</vs>
#                 <fltRt>0</fltRt>
#                 <mkp>19060</mkp>
#                 <hipr>19060</hipr>
#                 <lopr>19030</lopr>
#                 <trqu>140</trqu>
#                 <trPrc>2665010</trPrc>
#                 <lstgStCnt>3000000</lstgStCnt>
#                 <mrktTotAmt>57090000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001290</srtnCd>
#                 <isinCd>KR7001290006</isinCd>
#                 <itmsNm>상상인증권</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>783</clpr>
#                 <vs>8</vs>
#                 <fltRt>1.03</fltRt>
#                 <mkp>771</mkp>
#                 <hipr>785</hipr>
#                 <lopr>768</lopr>
#                 <trqu>30494</trqu>
#                 <trPrc>23747607</trPrc>
#                 <lstgStCnt>108337120</lstgStCnt>
#                 <mrktTotAmt>84827964960</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001340</srtnCd>
#                 <isinCd>KR7001340009</isinCd>
#                 <itmsNm>백광산업</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>7790</clpr>
#                 <vs>230</vs>
#                 <fltRt>3.04</fltRt>
#                 <mkp>7520</mkp>
#                 <hipr>7830</hipr>
#                 <lopr>7400</lopr>
#                 <trqu>1451516</trqu>
#                 <trPrc>11102427500</trPrc>
#                 <lstgStCnt>44918407</lstgStCnt>
#                 <mrktTotAmt>349914390530</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001360</srtnCd>
#                 <isinCd>KR7001360007</isinCd>
#                 <itmsNm>삼성제약</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>2970</clpr>
#                 <vs>-30</vs>
#                 <fltRt>-1</fltRt>
#                 <mkp>2980</mkp>
#                 <hipr>3045</hipr>
#                 <lopr>2935</lopr>
#                 <trqu>172184</trqu>
#                 <trPrc>511250465</trPrc>
#                 <lstgStCnt>67162079</lstgStCnt>
#                 <mrktTotAmt>199471374630</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001380</srtnCd>
#                 <isinCd>KR7001380005</isinCd>
#                 <itmsNm>SG글로벌</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>1379</clpr>
#                 <vs>49</vs>
#                 <fltRt>3.68</fltRt>
#                 <mkp>1369</mkp>
#                 <hipr>1389</hipr>
#                 <lopr>1340</lopr>
#                 <trqu>117819</trqu>
#                 <trPrc>161255976</trPrc>
#                 <lstgStCnt>44964143</lstgStCnt>
#                 <mrktTotAmt>62005553197</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001390</srtnCd>
#                 <isinCd>KR7001390004</isinCd>
#                 <itmsNm>KG케미칼</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>49200</clpr>
#                 <vs>-50</vs>
#                 <fltRt>-.1</fltRt>
#                 <mkp>49000</mkp>
#                 <hipr>49900</hipr>
#                 <lopr>48050</lopr>
#                 <trqu>312865</trqu>
#                 <trPrc>15330939750</trPrc>
#                 <lstgStCnt>13866096</lstgStCnt>
#                 <mrktTotAmt>682211923200</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001420</srtnCd>
#                 <isinCd>KR7001420009</isinCd>
#                 <itmsNm>태원물산</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>4745</clpr>
#                 <vs>-165</vs>
#                 <fltRt>-3.36</fltRt>
#                 <mkp>4935</mkp>
#                 <hipr>4935</hipr>
#                 <lopr>4670</lopr>
#                 <trqu>14564</trqu>
#                 <trPrc>69795860</trPrc>
#                 <lstgStCnt>7600000</lstgStCnt>
#                 <mrktTotAmt>36062000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001430</srtnCd>
#                 <isinCd>KR7001430008</isinCd>
#                 <itmsNm>세아베스틸지주</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>27950</clpr>
#                 <vs>-1400</vs>
#                 <fltRt>-4.77</fltRt>
#                 <mkp>29150</mkp>
#                 <hipr>29250</hipr>
#                 <lopr>27900</lopr>
#                 <trqu>212829</trqu>
#                 <trPrc>6027272400</trPrc>
#                 <lstgStCnt>35862119</lstgStCnt>
#                 <mrktTotAmt>1002346226050</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001440</srtnCd>
#                 <isinCd>KR7001440007</isinCd>
#                 <itmsNm>대한전선</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>13820</clpr>
#                 <vs>-130</vs>
#                 <fltRt>-.93</fltRt>
#                 <mkp>13990</mkp>
#                 <hipr>14000</hipr>
#                 <lopr>13800</lopr>
#                 <trqu>392889</trqu>
#                 <trPrc>5438800280</trPrc>
#                 <lstgStCnt>124447300</lstgStCnt>
#                 <mrktTotAmt>1719861686000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001450</srtnCd>
#                 <isinCd>KR7001450006</isinCd>
#                 <itmsNm>현대해상</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>29050</clpr>
#                 <vs>-1050</vs>
#                 <fltRt>-3.49</fltRt>
#                 <mkp>29800</mkp>
#                 <hipr>30100</hipr>
#                 <lopr>28900</lopr>
#                 <trqu>404515</trqu>
#                 <trPrc>11820334700</trPrc>
#                 <lstgStCnt>89400000</lstgStCnt>
#                 <mrktTotAmt>2597070000000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001460</srtnCd>
#                 <isinCd>KR7001460005</isinCd>
#                 <itmsNm>BYC</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>427500</clpr>
#                 <vs>9500</vs>
#                 <fltRt>2.27</fltRt>
#                 <mkp>418000</mkp>
#                 <hipr>427500</hipr>
#                 <lopr>418000</lopr>
#                 <trqu>163</trqu>
#                 <trPrc>68922500</trPrc>
#                 <lstgStCnt>624615</lstgStCnt>
#                 <mrktTotAmt>267022912500</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001465</srtnCd>
#                 <isinCd>KR7001461003</isinCd>
#                 <itmsNm>BYC우</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>140200</clpr>
#                 <vs>-1400</vs>
#                 <fltRt>-.99</fltRt>
#                 <mkp>141600</mkp>
#                 <hipr>141600</hipr>
#                 <lopr>140100</lopr>
#                 <trqu>178</trqu>
#                 <trPrc>25000900</trPrc>
#                 <lstgStCnt>215385</lstgStCnt>
#                 <mrktTotAmt>30196977000</mrktTotAmt>
#             </item>
#             <item>
#                 <basDt>20230717</basDt>
#                 <srtnCd>001470</srtnCd>
#                 <isinCd>KR7001470004</isinCd>
#                 <itmsNm>삼부토건</itmsNm>
#                 <mrktCtg>KOSPI</mrktCtg>
#                 <clpr>5010</clpr>
#                 <vs>215</vs>
#                 <fltRt>4.48</fltRt>
#                 <mkp>5480</mkp>
#                 <hipr>5500</hipr>
#                 <lopr>4945</lopr>
#                 <trqu>62569003</trqu>
#                 <trPrc>321198041350</trPrc>
#                 <lstgStCnt>197673375</lstgStCnt>
#                 <mrktTotAmt>990343608750</mrktTotAmt>
#             </item>
#         </items>
#     </body>
# </response>

# %%
type(content)
# Out:
# str

# %%
content[:1000]
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<response>\n    <header>\n        <resultCode>00</resultCode>\n        <resultMsg>NORMAL SERVICE.</resultMsg>\n    </header>\n    <body>\n        <numOfRows>100</numOfRows>\n        <pageNo>1</pageNo>\n        <totalCount>2728</totalCount>\n        <items>\n            <item>\n                <basDt>20230717</basDt>\n                <srtnCd>900110</srtnCd>\n                <isinCd>HK0000057197</isinCd>\n                <itmsNm>이스트아시아홀딩스</itmsNm>\n                <mrktCtg>KOSDAQ</mrktCtg>\n                <clpr>150</clpr>\n                <vs>-1</vs>\n                <fltRt>-.66</fltRt>\n                <mkp>151</mkp>\n                <hipr>151</hipr>\n                <lopr>148</lopr>\n                <trqu>1780351</trqu>\n                <trPrc>266398657</trPrc>\n                <lstgStCnt>291932050</lstgStCnt>\n                <mrktTotAmt>43789807500</mrktTotAmt>\n            </item>\n            <item>\n                <basDt>20230717</basDt>\n             '
